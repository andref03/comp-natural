# %%
# %pip install numpy matplotlib pandas

import random
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def gerar_populacao(m, n):
    matriz = np.zeros((m, n), dtype=int)
    for i in range(m):
        for j in range(n):
            matriz[i][j] = random.randint(1, n)
    return matriz

def verifica_conflitos(matriz):

    conflitos = np.zeros((matriz.shape[0], 1), dtype=int)

    # verifica conflitos para cada indivíduo
    for i in range(matriz.shape[0]):
        for j in range(matriz.shape[1]):
            for k in range(j + 1, matriz.shape[1]):

                # conflito na mesma linha/posição de rainha
                if matriz[i][k] == matriz[i][j]:
                    conflitos[i] += 1

                # conflito na diagonal
                if abs(j - k) == abs(matriz[i][j] - matriz[i][k]):
                    conflitos[i] += 1

    return conflitos, conflitos.sum()

def seleciona_pai_binario(conflitos):
    
    # seleciona dois indivíduos aleatórios
    pai_01_index = random.randint(0, len(conflitos) - 1)
    pai_02_index = random.randint(0, len(conflitos) - 1)

    # garante que os dois indivíduos selecionados sejam diferentes
    while pai_02_index == pai_01_index:
        pai_02_index = random.randint(0, len(conflitos) - 1)

    if conflitos[pai_01_index][0] < conflitos[pai_02_index][0]:
        return pai_01_index
    else:
        return pai_02_index

def cruzamento(pai_01, pai_02, ponto_corte):

    # gera dois filhos a partir de dois pais e um ponto de corte
    filho_01 = np.concatenate((pai_01[:ponto_corte], pai_02[ponto_corte:]))
    filho_02 = np.concatenate((pai_02[:ponto_corte], pai_01[ponto_corte:]))

    return filho_01, filho_02

def mutacao(filho, taxa, n):
    
    # mutação simples que altera um gene aleatório do filho com uma nova posição aleatória
    if random.random() < taxa:
        posicao = random.randint(0, len(filho) - 1)
        novo_valor = random.randint(1, n)

        while novo_valor == filho[posicao]:
            novo_valor = random.randint(1, n)

        filho[posicao] = novo_valor

    return filho

# função gerada por IA
def imprime_tabuleiro(individuo):
    n = len(individuo)
    print("\nTABULEIRO DA MELHOR SOLUÇÃO:\n")

    for linha in range(1, n + 1):
        for coluna in range(n):
            if individuo[coluna] == linha:
                print(" Q ", end="")
            else:
                print(" . ", end="")
        print()

# função criada com auxílio da IA
def executar_queens(m, n, geracoes, taxa_mutacao):

    # marcando o tempo
    inicio = time.time()

    # população inicial
    matriz_inicial = gerar_populacao(m, n)
    conflitos_iniciais, qtdd_conflitos_inicial = verifica_conflitos(matriz_inicial)

    matriz_atual = matriz_inicial.copy()

    # históricos para gráficos
    historico_media = []
    historico_melhor = []

    # variáveis para acompanhar melhor global
    melhor_conflito_global = 999999
    melhor_individuo_global = None
    melhor_geracao_global = -1

    # registra primeira geração com solução perfeita (0 conflitos)
    geracao_convergencia = None

    for geracao in range(geracoes):

        # avalia população atual
        conflitos, conflitos_total = verifica_conflitos(matriz_atual)
        media_conflitos = conflitos_total / m
        melhor_conflito_geracao = int(conflitos.min())
        melhor_indice_geracao = int(np.argmin(conflitos)) # índice do melhor indivíduo (menor conflito) na geração atual

        historico_media.append(media_conflitos)
        historico_melhor.append(melhor_conflito_geracao)

        # guarda melhor global
        if melhor_conflito_geracao < melhor_conflito_global:
            melhor_conflito_global = melhor_conflito_geracao
            melhor_individuo_global = matriz_atual[melhor_indice_geracao].copy()
            melhor_geracao_global = geracao + 1

        # registra a primeira geração em que apareceu solução perfeita
        if geracao_convergencia is None and melhor_conflito_geracao == 0:
            geracao_convergencia = geracao + 1

        # nova geração
        nova_populacao = np.zeros_like(matriz_atual)

        indice = 0
        while indice < m:
            pai_01_index = seleciona_pai_binario(conflitos)
            pai_02_index = seleciona_pai_binario(conflitos)

            pai_01 = matriz_atual[pai_01_index]
            pai_02 = matriz_atual[pai_02_index]

            ponto_corte = random.randint(1, n-1)
            filho_01, filho_02 = cruzamento(pai_01, pai_02, ponto_corte)

            filho_01 = mutacao(filho_01, taxa_mutacao, n)
            filho_02 = mutacao(filho_02, taxa_mutacao, n)

            nova_populacao[indice] = filho_01
            if indice + 1 < m:
                nova_populacao[indice + 1] = filho_02

            indice += 2

        matriz_atual = nova_populacao.copy()

    # avaliação final
    conflitos_finais, qtdd_conflitos_final = verifica_conflitos(matriz_atual)
    fim = time.time()
    tempo_execucao = fim - inicio

    # percentual de indivíduos perfeitos na população final (métrica auxiliar)
    qtdd_solucoes_perfeitas = int(np.sum(conflitos_finais == 0))
    percentual_pop_final_zerada = (qtdd_solucoes_perfeitas / m) * 100

    # 1 = encontrou solução perfeita, 0 = não encontrou
    sucesso_execucao = 1 if melhor_conflito_global == 0 else 0

    # se nunca convergiu, usamos -1 para indicar ausência de solução perfeita
    if geracao_convergencia is None:
        geracao_convergencia = -1

    return {
        "populacao_inicial": matriz_inicial,
        "populacao_final": matriz_atual,
        "conflitos_iniciais": conflitos_iniciais,
        "conflitos_finais": conflitos_finais,
        "qtdd_conflitos_inicial": int(qtdd_conflitos_inicial),
        "qtdd_conflitos_final": int(qtdd_conflitos_final),
        "historico_media": historico_media,
        "historico_melhor": historico_melhor,
        "melhor_conflito_global": int(melhor_conflito_global),
        "melhor_individuo_global": melhor_individuo_global,
        "melhor_geracao_global": melhor_geracao_global,
        "geracao_convergencia": geracao_convergencia,
        "tempo_execucao": tempo_execucao,
        "sucesso_execucao": sucesso_execucao,
        "percentual_pop_final_zerada": percentual_pop_final_zerada
    }

# =====================================
# FUNÇÃO AUXILIAR PARA CADA VALOR DE N
# =====================================

# função aprimorada por IA, com base no código anterior implementado por mim
def executar_bloco_experimento(n, m=50, geracoes=50, taxa_mutacao=0.05, num_execucoes=30):

    resultados_execucoes = []

    print("\n\n=======================================\n")

    for execucao in range(num_execucoes):
        print(f"Executando experimento n={n} | {execucao + 1}/{num_execucoes}...")
        resultado = executar_queens(m=m, n=n, geracoes=geracoes, taxa_mutacao=taxa_mutacao)
        resultados_execucoes.append(resultado)

    print("\nTodas as execuções concluídas.")

    tempos = [r["tempo_execucao"] for r in resultados_execucoes]

    # só considera execuções que realmente convergiram
    geracoes_conv_validas = [r["geracao_convergencia"] for r in resultados_execucoes if r["geracao_convergencia"] != -1]

    melhores_finais = [r["melhor_conflito_global"] for r in resultados_execucoes]
    sucessos_execucao = [r["sucesso_execucao"] for r in resultados_execucoes]
    percentuais_pop = [r["percentual_pop_final_zerada"] for r in resultados_execucoes]

    tempo_medio = np.mean(tempos)
    melhor_fitness_medio = np.mean(melhores_finais)

    if len(geracoes_conv_validas) > 0:
        geracoes_medias = np.mean(geracoes_conv_validas)
    else:
        geracoes_medias = -1

    # porcentagem de execuções que encontraram solução perfeita
    taxa_sucesso = np.mean(sucessos_execucao) * 100

    # métrica auxiliar
    percentual_pop_final_zerada_medio = np.mean(percentuais_pop)

    # tabelas geradas por IA
    print("\n===== TABELA RESUMO =====")
    print(f"n = {n}")
    print(f"Tempo médio de execução: {tempo_medio:.4f} s")

    if geracoes_medias == -1:
        print("Número médio de gerações até convergência: não houve convergência")
    else:
        print(f"Número médio de gerações até convergência: {geracoes_medias:.2f}")

    print(f"Taxa de sucesso: {taxa_sucesso:.2f}%")
    print(f"Melhor fitness médio encontrado: {melhor_fitness_medio:.2f}")
    print(f"Percentual médio de soluções perfeitas na população final: {percentual_pop_final_zerada_medio:.2f}%")

    # histórico para gráficos
    historicos_media = np.array([r["historico_media"] for r in resultados_execucoes])
    historicos_melhor = np.array([r["historico_melhor"] for r in resultados_execucoes])

    media_das_medias = np.mean(historicos_media, axis=0)
    media_dos_melhores = np.mean(historicos_melhor, axis=0)

    # gráficos gerados por IA

    # gráfico fitness médio
    plt.figure(figsize=(12, 6))
    plt.plot(range(1, len(media_das_medias) + 1), media_das_medias, marker='o')
    plt.xlabel('Geração')
    plt.ylabel('Fitness médio (média de conflitos)')
    plt.title(f'Convergência média - Fitness médio ({n}-Rainhas, {num_execucoes} execuções)')
    plt.grid(True)
    plt.show()

    # gráfico melhor fitness
    plt.figure(figsize=(12, 6))
    plt.plot(range(1, len(media_dos_melhores) + 1), media_dos_melhores, marker='o')
    plt.xlabel('Geração')
    plt.ylabel('Melhor fitness médio')
    plt.title(f'Convergência média - Melhor Fitness ({n}-Rainhas, {num_execucoes} execuções)')
    plt.grid(True)
    plt.show()

    # melhor execução
    melhor_execucao = min(resultados_execucoes, key=lambda r: r["melhor_conflito_global"])
    melhor_individuo = melhor_execucao["melhor_individuo_global"]

    print("===== MELHOR SOLUÇÃO ENCONTRADA ENTRE AS EXECUÇÕES =====")
    print(f"Melhor conflito: {melhor_execucao['melhor_conflito_global']}")
    print(f"Geração em que apareceu: {melhor_execucao['melhor_geracao_global']}")
    print(f"Indivíduo: {melhor_individuo}")

    imprime_tabuleiro(melhor_individuo)

    return {
        "n": n,
        "tempo_medio": tempo_medio,
        "geracoes_medias": geracoes_medias,
        "taxa_sucesso": taxa_sucesso,
        "melhor_fitness_medio": melhor_fitness_medio,
        "percentual_pop_final_zerada_medio": percentual_pop_final_zerada_medio
    }


# ================================================
# EXECUTANDO OS EXPERIMENTOS PARA CADA VALOR DE N
# ================================================

tabela_comparativa = []

# Para 50 indivíduos, 8 rainhas, 50 gerações
resumo_8 = executar_bloco_experimento(n=8, m=50, geracoes=50, taxa_mutacao=0.05, num_execucoes=30)
tabela_comparativa.append(resumo_8)

# Para 50 indivíduos, 15 rainhas, 50 gerações
resumo_15 = executar_bloco_experimento(n=15, m=50, geracoes=50, taxa_mutacao=0.05, num_execucoes=30)
tabela_comparativa.append(resumo_15)

## Para 50 indivíduos, 20 rainhas, 50 gerações
resumo_20 = executar_bloco_experimento(n=20, m=50, geracoes=50, taxa_mutacao=0.05, num_execucoes=30)
tabela_comparativa.append(resumo_20)

# Para 50 indivíduos, 30 rainhas, 50 gerações
resumo_30 = executar_bloco_experimento(n=30, m=50, geracoes=50, taxa_mutacao=0.05, num_execucoes=30)
tabela_comparativa.append(resumo_30)


# =========================
# TABELA COMPARATIVA FINAL
# =========================

# estrutura da tabela gerada por IA

df_tabela = pd.DataFrame(tabela_comparativa)
df_tabela_formatada = df_tabela.copy()

df_tabela_formatada = df_tabela_formatada.rename(columns={
    "n": "Instância (n)",
    "tempo_medio": "Tempo médio (s)",
    "geracoes_medias": "Gerações médias até convergência",
    "taxa_sucesso": "Taxa de sucesso (%)",
    "melhor_fitness_medio": "Melhor fitness médio",
    "percentual_pop_final_zerada_medio": "% de indivíduos perfeitos na população final"
})

# formatando valores
df_tabela_formatada["Tempo médio (s)"] = df_tabela_formatada["Tempo médio (s)"].round(4)
df_tabela_formatada["Gerações médias até convergência"] = df_tabela_formatada["Gerações médias até convergência"].round(2)
df_tabela_formatada["Taxa de sucesso (%)"] = df_tabela_formatada["Taxa de sucesso (%)"].round(2)
df_tabela_formatada["Melhor fitness médio"] = df_tabela_formatada["Melhor fitness médio"].round(2)
df_tabela_formatada["% de indivíduos perfeitos na população final"] = df_tabela_formatada["% de indivíduos perfeitos na população final"].round(2)

print("\n\n================ TABELA COMPARATIVA FINAL ================\n")
print(df_tabela_formatada.to_string(index=False))
# Out:
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (2.4.3)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
#
#
# =======================================
#
# Executando experimento n=8 | 1/30...
# Executando experimento n=8 | 2/30...
# Executando experimento n=8 | 3/30...
# Executando experimento n=8 | 4/30...
# Executando experimento n=8 | 5/30...
# Executando experimento n=8 | 6/30...
# Executando experimento n=8 | 7/30...
# Executando experimento n=8 | 8/30...
# Executando experimento n=8 | 9/30...
# Executando experimento n=8 | 10/30...
# Executando experimento n=8 | 11/30...
# Executando experimento n=8 | 12/30...
# Executando experimento n=8 | 13/30...
# Executando experimento n=8 | 14/30...
# Executando experimento n=8 | 15/30...
# Executando experimento n=8 | 16/30...
# Executando experimento n=8 | 17/30...
# Executando experimento n=8 | 18/30...
# Executando experimento n=8 | 19/30...
# Executando experimento n=8 | 20/30...
# Executando experimento n=8 | 21/30...
# Executando experimento n=8 | 22/30...
# Executando experimento n=8 | 23/30...
# Executando experimento n=8 | 24/30...
# Executando experimento n=8 | 25/30...
# Executando experimento n=8 | 26/30...
# Executando experimento n=8 | 27/30...
# Executando experimento n=8 | 28/30...
# Executando experimento n=8 | 29/30...
# Executando experimento n=8 | 30/30...
#
# Todas as execuções concluídas.
#
# ===== TABELA RESUMO =====
# n = 8
# Tempo médio de execução: 0.0558 s
# Número médio de gerações até convergência: 16.00
# Taxa de sucesso: 33.33%
# Melhor fitness médio encontrado: 0.80
# Percentual médio de soluções perfeitas na população final: 18.67%
# ===== MELHOR SOLUÇÃO ENCONTRADA ENTRE AS EXECUÇÕES =====
# Melhor conflito: 0
# Geração em que apareceu: 24
# Indivíduo: [5 3 1 6 8 2 4 7]
#
# TABULEIRO DA MELHOR SOLUÇÃO:
#
#  .  .  Q  .  .  .  .  .
#  .  .  .  .  .  Q  .  .
#  .  Q  .  .  .  .  .  .
#  .  .  .  .  .  .  Q  .
#  Q  .  .  .  .  .  .  .
#  .  .  .  Q  .  .  .  .
#  .  .  .  .  .  .  .  Q
#  .  .  .  .  Q  .  .  .
#
#
# =======================================
#
# Executando experimento n=15 | 1/30...
# Executando experimento n=15 | 2/30...
# Executando experimento n=15 | 3/30...
# Executando experimento n=15 | 4/30...
# Executando experimento n=15 | 5/30...
# Executando experimento n=15 | 6/30...
# Executando experimento n=15 | 7/30...
# Executando experimento n=15 | 8/30...
# Executando experimento n=15 | 9/30...
# Executando experimento n=15 | 10/30...
# Executando experimento n=15 | 11/30...
# Executando experimento n=15 | 12/30...
# Executando experimento n=15 | 13/30...
# Executando experimento n=15 | 14/30...
# Executando experimento n=15 | 15/30...
# Executando experimento n=15 | 16/30...
# Executando experimento n=15 | 17/30...
# Executando experimento n=15 | 18/30...
# Executando experimento n=15 | 19/30...
# Executando experimento n=15 | 20/30...
# Executando experimento n=15 | 21/30...
# Executando experimento n=15 | 22/30...
# Executando experimento n=15 | 23/30...
# Executando experimento n=15 | 24/30...
# Executando experimento n=15 | 25/30...
# Executando experimento n=15 | 26/30...
# Executando experimento n=15 | 27/30...
# Executando experimento n=15 | 28/30...
# Executando experimento n=15 | 29/30...
# Executando experimento n=15 | 30/30...
#
# Todas as execuções concluídas.
#
# ===== TABELA RESUMO =====
# n = 15
# Tempo médio de execução: 0.1899 s
# Número médio de gerações até convergência: não houve convergência
# Taxa de sucesso: 0.00%
# Melhor fitness médio encontrado: 2.93
# Percentual médio de soluções perfeitas na população final: 0.00%
# ===== MELHOR SOLUÇÃO ENCONTRADA ENTRE AS EXECUÇÕES =====
# Melhor conflito: 1
# Geração em que apareceu: 14
# Indivíduo: [13  4  2  9  6 13  3 14 12  8 15  5  7 11  1]
#
# TABULEIRO DA MELHOR SOLUÇÃO:
#
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q
#  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .
#  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .
#  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .
#  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .
#  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .
#  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .
#  Q  .  .  .  .  Q  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .
#
#
# =======================================
#
# Executando experimento n=20 | 1/30...
# Executando experimento n=20 | 2/30...
# Executando experimento n=20 | 3/30...
# Executando experimento n=20 | 4/30...
# Executando experimento n=20 | 5/30...
# Executando experimento n=20 | 6/30...
# Executando experimento n=20 | 7/30...
# Executando experimento n=20 | 8/30...
# Executando experimento n=20 | 9/30...
# Executando experimento n=20 | 10/30...
# Executando experimento n=20 | 11/30...
# Executando experimento n=20 | 12/30...
# Executando experimento n=20 | 13/30...
# Executando experimento n=20 | 14/30...
# Executando experimento n=20 | 15/30...
# Executando experimento n=20 | 16/30...
# Executando experimento n=20 | 17/30...
# Executando experimento n=20 | 18/30...
# Executando experimento n=20 | 19/30...
# Executando experimento n=20 | 20/30...
# Executando experimento n=20 | 21/30...
# Executando experimento n=20 | 22/30...
# Executando experimento n=20 | 23/30...
# Executando experimento n=20 | 24/30...
# Executando experimento n=20 | 25/30...
# Executando experimento n=20 | 26/30...
# Executando experimento n=20 | 27/30...
# Executando experimento n=20 | 28/30...
# Executando experimento n=20 | 29/30...
# Executando experimento n=20 | 30/30...
#
# Todas as execuções concluídas.
#
# ===== TABELA RESUMO =====
# n = 20
# Tempo médio de execução: 0.3175 s
# Número médio de gerações até convergência: não houve convergência
# Taxa de sucesso: 0.00%
# Melhor fitness médio encontrado: 4.90
# Percentual médio de soluções perfeitas na população final: 0.00%
# ===== MELHOR SOLUÇÃO ENCONTRADA ENTRE AS EXECUÇÕES =====
# Melhor conflito: 3
# Geração em que apareceu: 40
# Indivíduo: [ 7 17  3 16 13  9  4  6  2 15  5  1  8 10 14 20 18 20  9 12]
#
# TABULEIRO DA MELHOR SOLUÇÃO:
#
#  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .
#  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .
#  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .
#  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  Q  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q
#  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .
#  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  Q  .  .
#
#
# =======================================
#
# Executando experimento n=30 | 1/30...
# Executando experimento n=30 | 2/30...
# Executando experimento n=30 | 3/30...
# Executando experimento n=30 | 4/30...
# Executando experimento n=30 | 5/30...
# Executando experimento n=30 | 6/30...
# Executando experimento n=30 | 7/30...
# Executando experimento n=30 | 8/30...
# Executando experimento n=30 | 9/30...
# Executando experimento n=30 | 10/30...
# Executando experimento n=30 | 11/30...
# Executando experimento n=30 | 12/30...
# Executando experimento n=30 | 13/30...
# Executando experimento n=30 | 14/30...
# Executando experimento n=30 | 15/30...
# Executando experimento n=30 | 16/30...
# Executando experimento n=30 | 17/30...
# Executando experimento n=30 | 18/30...
# Executando experimento n=30 | 19/30...
# Executando experimento n=30 | 20/30...
# Executando experimento n=30 | 21/30...
# Executando experimento n=30 | 22/30...
# Executando experimento n=30 | 23/30...
# Executando experimento n=30 | 24/30...
# Executando experimento n=30 | 25/30...
# Executando experimento n=30 | 26/30...
# Executando experimento n=30 | 27/30...
# Executando experimento n=30 | 28/30...
# Executando experimento n=30 | 29/30...
# Executando experimento n=30 | 30/30...
#
# Todas as execuções concluídas.
#
# ===== TABELA RESUMO =====
# n = 30
# Tempo médio de execução: 0.6837 s
# Número médio de gerações até convergência: não houve convergência
# Taxa de sucesso: 0.00%
# Melhor fitness médio encontrado: 10.07
# Percentual médio de soluções perfeitas na população final: 0.00%
# ===== MELHOR SOLUÇÃO ENCONTRADA ENTRE AS EXECUÇÕES =====
# Melhor conflito: 8
# Geração em que apareceu: 50
# Indivíduo: [ 7 29 20 28  9  4 14 10  3 26 30 13 23  1 12  6  2  6 19 29 17 11  3 27
#  16 18 20 27  8  5]
#
# TABULEIRO DA MELHOR SOLUÇÃO:
#
#  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .
#  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  Q  .  .  .  .  .  .  .  .  .  .  .  .
#  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .
#  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .
#  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  Q  .  .
#  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .
#  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#
#
# ================ TABELA COMPARATIVA FINAL (FORMATADA) ================
#
#  Instância (n)  Tempo médio (s)  Gerações médias até convergência  Taxa de sucesso (%)  Melhor fitness médio  % de indivíduos perfeitos na população final
#              8           0.0558                              16.0                33.33                  0.80                                         18.67
#             15           0.1899                              -1.0                 0.00                  2.93                                          0.00
#             20           0.3175                              -1.0                 0.00                  4.90                                          0.00
#             30           0.6837                              -1.0                 0.00                 10.07                                          0.00
